# %%
# %pip install boto3
# Out:
# Requirement already satisfied: boto3 in c:\users\benjiebubblessyd\anaconda3\lib\site-packages (1.24.28)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in c:\users\benjiebubblessyd\anaconda3\lib\site-packages (from boto3) (1.27.28)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\benjiebubblessyd\anaconda3\lib\site-packages (from boto3) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\benjiebubblessyd\anaconda3\lib\site-packages (from boto3) (0.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\benjiebubblessyd\anaconda3\lib\site-packages (from botocore<1.28.0,>=1.27.28->boto3) (1.26.11)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\benjiebubblessyd\anaconda3\lib\site-packages (from botocore<1.28.0,>=1.27.28->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\benjiebubblessyd\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.28.0,>=1.27.28->boto3) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import bs4
import requests
import pandas as pd
import numpy as np
import boto3

# %%
def get_basketball_stats(link='https://en.wikipedia.org/wiki/Michael_Jordan'):
    response = requests.get(link)
    soup = bs4.BeautifulSoup(response.text, 'html.parser')
    table=soup.find(class_='wikitable sortable')

    headers=table.tr
    titles=headers.find_all("abbr")
    data = {title['title']:[] for title in titles}

    for row in table.find_all('tr')[1:]:
    
        for key,a in zip(data.keys(),row.find_all("td")[2:]):
            data[key].append(''.join(c for c in a.text if (c.isdigit() or c == ".")))

    Min=min([len(x)  for x in data.values()])
    for key in data.keys():
    
        data[key]=list(map(lambda x: float(x), data[key][:Min]))
       
    return data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# %%
links=['https://en.wikipedia.org/wiki/Michael_Jordan','https://en.wikipedia.org/wiki/Kobe_Bryant','https://en.wikipedia.org/wiki/LeBron_James','https://en.wikipedia.org/wiki/Stephen_Curry']
names=['Michael Jordan','Kobe Bryant','Lebron James','Stephen Curry']

# %%
mj_dict=get_basketball_stats(links[0])
kb_dict=get_basketball_stats(links[1])
lj_dict=get_basketball_stats(links[2])
sc_dict=get_basketball_stats(links[3])

# %%
mj_pd = pd.DataFrame(mj_dict)
kb_pd = pd.DataFrame(kb_dict)
lj_pd = pd.DataFrame(lj_dict)
sc_pd = pd.DataFrame(sc_dict)

# %%
i = 0
for name in names:
    current_dict=get_basketball_stats(links[i])
    df = pd.DataFrame(current_dict)
    print(name)
    display(df)
    print(" \n")
    i+=1
# Out:
# Michael Jordan
#     Games played  Games started  Minutes per game  Field goal percentage  \
# 0           82.0           82.0              38.3                  0.515
# 1           18.0            7.0              25.1                  0.457
# 2           82.0           82.0              40.0                  0.482
# 3           82.0           82.0              40.4                  0.535
# 4           81.0           81.0              40.2                  0.538
# 5           82.0           82.0              39.0                  0.526
# 6           82.0           82.0              37.0                  0.539
# 7           80.0           80.0              38.8                  0.519
# 8           78.0           78.0              39.3                  0.495
# 9           17.0           17.0              39.3                  0.411
# 10          82.0           82.0              37.7                  0.495
# 11          82.0           82.0              37.9                  0.486
# 12          82.0           82.0              38.8                  0.465
# 13          60.0           53.0              34.9                  0.416
# 14          82.0           67.0              37.0                  0.445
#
#     3-point field-goal percentage  Free-throw percentage  Rebounds per game  \
# 0                           0.173                  0.845                6.5
# 1                           0.167                  0.840                3.6
# 2                           0.182                  0.857                5.2
# 3                           0.132                  0.841                5.5
# 4                           0.276                  0.850                8.0
# 5                           0.376                  0.848                6.9
# 6                           0.312                  0.851                6.0
# 7                           0.270                  0.832                6.4
# 8                           0.352                  0.837                6.7
# 9                           0.500                  0.801                6.9
# 10                          0.427                  0.834                6.6
# 11                          0.374                  0.833                5.9
# 12                          0.238                  0.784                5.8
# 13                          0.189                  0.790                5.7
# 14                          0.291                  0.821                6.1
#
#     Assists per game  Steals per game  Blocks per game  Points per game
# 0                5.9              2.4              0.8             28.2
# 1                2.9              2.1              1.2             22.7
# 2                4.6              2.9              1.5             37.1
# 3                5.9              3.2              1.6             35.0
# 4                8.0              2.9              0.8             32.5
# 5                6.3              2.8              0.7             33.6
# 6                5.5              2.7              1.0             31.5
# 7                6.1              2.3              0.9             30.1
# 8                5.5              2.8              0.8             32.6
# 9                5.3              1.8              0.8             26.9
# 10               4.3              2.2              0.5             30.4
# 11               4.3              1.7              0.5             29.6
# 12               3.5              1.7              0.5             28.7
# 13               5.2              1.4              0.4             22.9
# 14               3.8              1.5              0.5             20.0
#
#
# Kobe Bryant
#     Games played  Games started  Minutes per game  Field goal percentage  \
# 0           71.0            6.0              15.5                  0.417
# 1           79.0            1.0              26.0                  0.428
# 2           50.0           50.0              37.9                  0.465
# 3           66.0           62.0              38.2                  0.468
# 4           68.0           68.0              40.9                  0.464
# 5           80.0           80.0              38.3                  0.469
# 6           82.0           82.0              41.5                  0.451
# 7           65.0           64.0              37.6                  0.438
# 8           66.0           66.0              40.7                  0.433
# 9           80.0           80.0              41.0                  0.450
# 10          77.0           77.0              40.8                  0.463
# 11          82.0           82.0              38.9                  0.459
# 12          82.0           82.0              36.1                  0.467
# 13          73.0           73.0              38.8                  0.456
# 14          82.0           82.0              33.9                  0.451
# 15          58.0           58.0              38.5                  0.430
# 16          78.0           78.0              38.6                  0.463
# 17           6.0            6.0              29.5                  0.425
# 18          35.0           35.0              34.5                  0.373
# 19          66.0           66.0              28.2                  0.358
#
#     3-point field-goal percentage  Free-throw percentage  Rebounds per game  \
# 0                           0.375                  0.819                1.9
# 1                           0.341                  0.794                3.1
# 2                           0.267                  0.839                5.3
# 3                           0.319                  0.821                6.3
# 4                           0.305                  0.853                5.9
# 5                           0.250                  0.829                5.5
# 6                           0.383                  0.843                6.9
# 7                           0.327                  0.852                5.5
# 8                           0.339                  0.816                5.9
# 9                           0.347                  0.850                5.3
# 10                          0.344                  0.868                5.7
# 11                          0.361                  0.840                6.3
# 12                          0.351                  0.856                5.2
# 13                          0.329                  0.811                5.4
# 14                          0.323                  0.828                5.1
# 15                          0.303                  0.845                5.4
# 16                          0.324                  0.839                5.6
# 17                          0.188                  0.857                4.3
# 18                          0.293                  0.813                5.7
# 19                          0.285                  0.826                3.7
#
#     Assists per game  Steals per game  Blocks per game  Points per game
# 0                1.3              0.7              0.3              7.6
# 1                2.5              0.9              0.5             15.4
# 2                3.8              1.4              1.0             19.9
# 3                4.9              1.6              0.9             22.5
# 4                5.0              1.7              0.6             28.5
# 5                5.5              1.5              0.4             25.2
# 6                5.9              2.2              0.8             30.0
# 7                5.1              1.7              0.4             24.0
# 8                6.0              1.3              0.8             27.6
# 9                4.5              1.8              0.4             35.4
# 10               5.4              1.4              0.5             31.6
# 11               5.4              1.8              0.5             28.3
# 12               4.9              1.5              0.5             26.8
# 13               5.0              1.5              0.3             27.0
# 14               4.7              1.2              0.1             25.3
# 15               4.6              1.2              0.3             27.9
# 16               6.0              1.4              0.3             27.3
# 17               6.3              1.2              0.2             13.8
# 18               5.6              1.3              0.2             22.3
# 19               2.8              0.9              0.2             17.6
#
#
# Lebron James
#     Games played  Games started  Minutes per game  Field goal percentage  \
# 0           79.0           79.0              39.5                  0.417
# 1           80.0           80.0              42.4                  0.472
# 2           79.0           79.0              42.5                  0.480
# 3           78.0           78.0              40.9                  0.476
# 4           75.0           74.0              40.4                  0.484
# 5           81.0           81.0              37.7                  0.489
# 6           76.0           76.0              39.0                  0.503
# 7           79.0           79.0              38.8                  0.510
# 8           62.0           62.0              37.5                  0.531
# 9           76.0           76.0              37.9                  0.565
# 10          77.0           77.0              37.7                  0.567
# 11          69.0           69.0              36.1                  0.488
# 12          76.0           76.0              35.6                  0.520
# 13          74.0           74.0              37.8                  0.548
# 14          82.0           82.0              36.9                  0.542
# 15          55.0           55.0              35.2                  0.510
# 16          67.0           67.0              34.6                  0.493
# 17          45.0           45.0              33.4                  0.513
# 18          56.0           56.0              37.2                  0.524
# 19          55.0           54.0              35.5                  0.500
#
#     3-point field-goal percentage  Free-throw percentage  Rebounds per game  \
# 0                           0.290                  0.754                5.5
# 1                           0.351                  0.750                7.4
# 2                           0.335                  0.738                7.0
# 3                           0.319                  0.698                6.7
# 4                           0.315                  0.712                7.9
# 5                           0.344                  0.780                7.6
# 6                           0.333                  0.767                7.3
# 7                           0.330                  0.759                7.5
# 8                           0.362                  0.771                7.9
# 9                           0.406                  0.753                8.0
# 10                          0.379                  0.750                6.9
# 11                          0.354                  0.710                6.0
# 12                          0.309                  0.731                7.4
# 13                          0.363                  0.674                8.6
# 14                          0.367                  0.731                8.6
# 15                          0.339                  0.665                8.5
# 16                          0.348                  0.693                7.8
# 17                          0.365                  0.698                7.7
# 18                          0.359                  0.756                8.2
# 19                          0.321                  0.768                8.3
#
#     Assists per game  Steals per game  Blocks per game  Points per game
# 0                5.9              1.6              0.7             20.9
# 1                7.2              2.2              0.7             27.2
# 2                6.6              1.6              0.8             31.4
# 3                6.0              1.6              0.7             27.3
# 4                7.2              1.8              1.1             30.0
# 5                7.2              1.7              1.1             28.4
# 6                8.6              1.6              1.0             29.7
# 7                7.0              1.6              0.6             26.7
# 8                6.2              1.9              0.8             27.1
# 9                7.3              1.7              0.9             26.8
# 10               6.4              1.6              0.3             27.1
# 11               7.4              1.6              0.7             25.3
# 12               6.8              1.4              0.6             25.3
# 13               8.7              1.2              0.6             26.4
# 14               9.1              1.4              0.9             27.5
# 15               8.3              1.3              0.6             27.4
# 16              10.2              1.2              0.5             25.3
# 17               7.8              1.1              0.6             25.0
# 18               6.2              1.3              1.1             30.3
# 19               6.8              0.9              0.6             28.9
#
#
# Stephen Curry
#     Games played  Games started  Minutes per game  Field goal percentage  \
# 0           80.0           77.0              36.2                  0.462
# 1           74.0           74.0              33.6                  0.480
# 2           26.0           23.0              28.2                  0.490
# 3           78.0           78.0              38.2                  0.451
# 4           78.0           78.0              36.5                  0.471
# 5           80.0           80.0              32.7                  0.487
# 6           79.0           79.0              34.2                  0.504
# 7           79.0           79.0              33.4                  0.468
# 8           51.0           51.0              32.0                  0.495
# 9           69.0           69.0              33.8                  0.472
# 10           5.0            5.0              27.8                  0.402
# 11          63.0           63.0              34.2                  0.482
# 12          64.0           64.0              34.5                  0.437
# 13          56.0           56.0              34.7                  0.493
#
#     3-point field-goal percentage  Free-throw percentage  Rebounds per game  \
# 0                           0.437                  0.885                4.5
# 1                           0.442                  0.934                3.9
# 2                           0.455                  0.809                3.4
# 3                           0.453                  0.900                4.0
# 4                           0.424                  0.885                4.3
# 5                           0.443                  0.914                4.3
# 6                           0.454                  0.908                5.4
# 7                           0.411                  0.898                4.5
# 8                           0.423                  0.921                5.1
# 9                           0.437                  0.916                5.3
# 10                          0.245                  1.000                5.2
# 11                          0.421                  0.916                5.5
# 12                          0.380                  0.923                5.2
# 13                          0.427                  0.915                6.1
#
#     Assists per game  Steals per game  Blocks per game  Points per game
# 0                5.9              1.9              0.2             17.5
# 1                5.8              1.5              0.3             18.6
# 2                5.3              1.5              0.3             14.7
# 3                6.9              1.6              0.2             22.9
# 4                8.5              1.6              0.2             24.0
# 5                7.7              2.0              0.2             23.8
# 6                6.7              2.1              0.2             30.1
# 7                6.6              1.8              0.2             25.3
# 8                6.1              1.6              0.2             26.4
# 9                5.2              1.3              0.4             27.3
# 10               6.6              1.0              0.4             20.8
# 11               5.8              1.2              0.1             32.0
# 12               6.3              1.3              0.4             25.5
# 13               6.3              0.9              0.4             29.4

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(mj_pd[['Points per game']],label='Michael Jordan')
plt.legend()
plt.xlabel('Years')
plt.ylabel('Points per game')
# Out:
# Text(0, 0.5, 'Points per game')

# %%
plt.plot(kb_pd[['Points per game']],label='Kobe Bryant')
plt.legend()
plt.xlabel('Years')
plt.ylabel('Points per game')
# Out:
# Text(0, 0.5, 'Points per game')

# %%
plt.plot(lj_pd[['Points per game']],label='Lebron James')
plt.legend()
plt.xlabel('Years')
plt.ylabel('Points per game')
# Out:
# Text(0, 0.5, 'Points per game')

# %%
plt.plot(sc_pd[['Points per game']],label='Stephen Curry')
plt.legend()
plt.xlabel('Years')
plt.ylabel('Points per game')
# Out:
# Text(0, 0.5, 'Points per game')

# %%
Michael_jordan_dict=get_basketball_stats(links[0])
Kobe_bryant_dict = get_basketball_stats(links[1])
Lebron_james_dict =get_basketball_stats(links[2])
Stephen_curry_dict = get_basketball_stats(links[3])
mj_df = pd.DataFrame.from_dict(Michael_jordan_dict)
kb_df = pd.DataFrame.from_dict(Kobe_bryant_dict)
lj_df = pd.DataFrame.from_dict(Lebron_james_dict)
sc_df = pd.DataFrame.from_dict(Stephen_curry_dict)

# %%
csv_name = 'MJ1.csv'
mj_df.to_csv(csv_name)
csv_name = 'KB1.csv'
kb_df.to_csv(csv_name)
csv_name = 'LJ1.csv'
lj_df.to_csv(csv_name)
csv_name = 'SC1.csv'
sc_df.to_csv(csv_name)
